# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as fit

# %%
dN=pd.read_csv('NOAA TOTAL.csv')
display(dN)
dN=dN.dropna()
# Out:
#           Date  Tmax  Tmin  Wasco CA
# 0     2/1/1960  68.0  42.0         0
# 1     2/2/1960  57.0  44.0         0
# 2     2/3/1960  60.0  40.0         0
# 3     2/4/1960  59.0  40.0         0
# 4     2/5/1960  60.0  37.0         0
# ..         ...   ...   ...       ...
# 488  2/25/2024  74.0  40.0         0
# 489  2/26/2024  72.0  42.0         0
# 490  2/27/2024  76.0  42.0         0
# 491  2/28/2024  76.0  42.0         0
# 492  2/29/2024  76.0  42.0         0
#
# [493 rows x 4 columns]

# %%
stx=dN["Tmax"]
stn=dN["Tmin"]
sdt=dN["Date"]
sav=(stx+stn)/2
display(sav)
# Out:
# 0      55.0
# 1      50.5
# 2      50.0
# 3      49.5
# 4      48.5
#        ...
# 488    57.0
# 489    57.0
# 490    59.0
# 491    59.0
# 492    59.0
# Length: 432, dtype: float64

# %%
def f(m,x,b):
  return (m*x)+b
p=[0,0]
dN.columns
# Out:
# Index(['Date', 'Tmax', 'Tmin', 'Wasco CA'], dtype='object')

# %%
plt.figure()
plt.scatter(sdt,stx,label="Tmax",color="#d6644b")
plt.scatter(sdt,stn,label="Tmin",color="#080878")
plt.title(dN.columns[3]+" Minimally Processed")
plt.xlabel("Date")
plt.ylabel("Temperature(F)")
plt.legend()
plt.show()
